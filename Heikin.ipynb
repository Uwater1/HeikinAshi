# %% [markdown]
# <a href="https://colab.research.google.com/github/Uwater1/HeikinAshi/blob/main/Heikin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download file & csv

# %%
# !wget https://raw.githubusercontent.com/Uwater1/HeikinAshi/refs/heads/main/heikinAshi.py && wget https://raw.githubusercontent.com/Uwater1/HeikinAshi/refs/heads/main/IVV.csv
# Out:
# --2025-12-01 19:14:02--  https://raw.githubusercontent.com/Uwater1/HeikinAshi/refs/heads/main/heikinAshi.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13315 (13K) [text/plain]
# Saving to: ‘heikinAshi.py’
#
# heikinAshi.py       100%[===================>]  13.00K  --.-KB/s    in 0s
#
# 2025-12-01 19:14:02 (25.6 MB/s) - ‘heikinAshi.py’ saved [13315/13315]
#
# --2025-12-01 19:14:02--  https://raw.githubusercontent.com/Uwater1/HeikinAshi/refs/heads/main/IVV.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %% [markdown]
# Download requirements

# %%
# !wget https://raw.githubusercontent.com/Uwater1/HeikinAshi/refs/heads/main/requirements.txt && pip install -r requirements.txt
# Out:
# --2025-12-01 19:14:12--  https://raw.githubusercontent.com/Uwater1/HeikinAshi/refs/heads/main/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48 [text/plain]
# Saving to: ‘requirements.txt’
#
# requirements.txt    100%[===================>]      48  --.-KB/s    in 0s
#
# 2025-12-01 19:14:12 (823 KB/s) - ‘requirements.txt’ saved [48/48]
#
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 12.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# Then run the program

# %%
# !python heikinAshi.py IVV.csv # Open the terminal downstairs and copy & paste this command
# Out:
# /usr/local/lib/python3.12/dist-packages/backtesting/_plotting.py:55: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support, such as old IDEs. Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
# /usr/local/lib/python3.12/dist-packages/backtesting/backtesting.py:1624: UserWarning: Searching for best of 46656 configurations.
#   output = _optimize_grid()
# Traceback (most recent call last):
#   File "/content/heikinAshi.py", line 414, in <module>
#     run(sys.argv[1])
#   File "/content/heikinAshi.py", line 354, in run
#     stats, heatmap = bt.optimize(
#                      ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/backtesting/backtesting.py", line 1624, in optimize
#     output = _optimize_grid()
#              ^^^^^^^^^^^^^^^^
# ...
